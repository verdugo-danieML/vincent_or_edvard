# %%
#|default_exp app

# %%
from duckduckgo_search import ddg_images
from fastcore.all import *

# %% [markdown]
# ## step 1: Download images

# %%
vincent_van_gogh = ['Head of a Peasant Woman - by Vincent van Gogh',
                    'Starry Night over the Rhone - by Vincent van Gogh',
                    'Starry Night - by Vincent van Gogh',
                    'Cafe Terrace at Night - by Vincent van Gogh',
                    'The Sunflowers - by Vincent van Gogh',
                    'Self Portraits - by Vincent van Gogh',
                    'The Night Cafe - by Vincent van Gogh',
                    'Still Life with Irises - by Vincent van Gogh',
                    'The Langlois Bridge at Arles - by Vincent van Gogh',
                    'Enclosed Field with Ploughman - by Vincent van Gogh',
                    'Landscape with Snow - by Vincent van Gogh',
                    'Agostina Segatori Sitting in the Café du Tambourin - by Vincent van Gogh',
                    'The Road Menders - by Vincent van Gogh',
                    'Tree Roots - by Vincent van Gogh',
                    'Vase with Daisies and Poppies - by Vincent van Gogh',
                    'Houses in Auvers - by Vincent van Gogh',
                    'Irises - by Vincent van Gogh',
                    'A Meadow in the Mountains: Le Mas de Saint-Paul - by Vincent van Gogh',
                    'Almond Blossom - by Vincent van Gogh',
                    'Landscape near Auvers: Wheatfields - by Vincent van Gogh',
                    'Landscape with Olive Trees - by Vincent van Gogh',
                    'Still Life with Potatoes - by Vincent van Gogh',
                    'Self Portrait with Bandaged Ear and Pipe - by Vincent van Gogh',
                    'Seascape at Saintes Maries - by Vincent van Gogh',
                    'Quay with Men Unloading Sand Barges - by Vincent van Gogh',
                    'The Enclosed Field at Sunrise - by Vincent van Gogh',
                    'The Painter on His Way to Work - by Vincent van Gogh',
                    'Seascape near Les Saintes-Maries-de-la-Mer - by Vincent van Gogh',
                    'Imperial Fritillaries in a Copper Vase - by Vincent van Gogh',
                    'Harvest, in Provence - by Vincent van Gogh',
                    'The Aliscamps at Arles - by Vincent van Gogh',
                    'Still Life with Coffee Pot - by Vincent van Gogh',
                    'Outskirts of Paris near Montmartre - by Vincent van Gogh',
                    'Vase with Pink Roses - by Vincent van Gogh',
                    'Portrait of Adeline Ravoux - by Vincent van Gogh',
                    'Tree Trunks in the Grass - by Vincent van Gogh',
                    'The Ravine - by Vincent van Gogh',
                    'Still Life with Two Sunflowers - by Vincent van Gogh',
                    'Memories of the Garden at Eetten - by Vincent van Gogh',
                    'Eugene Boch The Poet - by Vincent van Gogh',
                    'Augustine Roulin - by Vincent van Gogh',
                    'Road with Cypress and Star - by Vincent van Gogh',
                    'Cypresses - by Vincent van Gogh',
                    'Peasant Woman against Wheat Background - by Vincent van Gogh',
                    'Portrait of Joseph Roulin - by Vincent van Gogh',
                    'Seascape at Saintes Maries - by Vincent van Gogh',
                    'Thatched Cottages at Cordeville - by Vincent van Gogh',
                    'The italian - by Vincent van Gogh',
                    'Wheatfield with Crows - by Vincent van Gogh',
                    'Young man in a cap - by Vincent van Gogh']

edvard_munch = ['Anxiety 1894 - by Edvard Munch',
                'Arrival of the Mail Boat 1890 - by Edvard Munch',
                'Asgardstrand from the Reinhardt Frieze 1906 - by Edvard Munch',
                'Ashes 1894 - by Edvard Munch',
                'At the Coffee Table 1883 - by Edvard Munch',
                'Attraction 1896 - by Edvard Munch',
                'August Strindberg 1892 - by Edvard Munch',
                'Aunt Karen in the Rocking Chair 1883 - by Edvard Munch',
                'Awakening Men From the Oslo University Aula decoration 1911 - by Edvard Munch',
                'Bathing Men 1907 - by Edvard Munch',
                'Birch in the Snow 1901 - by Edvard Munch',
                'Brothel Scene Zum sussen Madel From the series The Green Room 1907 - by Edvard Munch',
                'Building the Winter Studio Ekely 1929 - by Edvard Munch',
                'By the Deathbed Fever 1915 - by Edvard Munch',
                'By the Roulette c 1892 - by Edvard Munch',
                'By the Window 1940 - by Edvard Munch',
                'Children in the Street 1915 - by Edvard Munch',
                'Christian Gierloff 1910 - by Edvard Munch',
                'Christmas in the Brothel 1904 - by Edvard Munch',
                'Cupid and Psyche 1907 - by Edvard Munch',
                'Dagny Juel Przybyszewska 1893 - by Edvard Munch',
                'Death in the Sick Chamber 1895 - by Edvard Munch',
                'Death of Marat II 1907 - by Edvard Munch',
                'Dr Lindes House 1902 - by Edvard Munch',
                'Evening Melancholy I 1896 - by Edvard Munch',
                'Evening on Karl Johan Street 1892 - by Edvard Munch',
                'Eye in Eye 1894 - by Edvard Munch',
                'Fertility II 1902 - by Edvard Munch',
                'Workers on Their Way Home 1913 - by Edvard Munch',
                'Four Girls at Asgardstrand 1902 - by Edvard Munch',
                'Fragment of War The Storm 1919 - by Edvard Munch',
                'Girl Yawning 1913 - by Edvard Munch',
                'Golgotha 1900 - by Edvard Munch',
                'Head of a Dog 1930s - by Edvard Munch',
                'High Summer II 1915 - by Edvard Munch',
                'House in Moonlight 1895 - by Edvard Munch',
                'Jealousy 1895 - by Edvard Munch',
                'Jealousy From the series The Green Room 1907 - by Edvard Munch',
                'Madonna 1894 - by Edvard Munch',
                'Meeting in Outer Space 1899 - by Edvard Munch',
                'The Dead Mother and the Child 1897 - by Edvard Munch',
                'Self Portrait with Burning Cigarette 1895 - by Edvard Munch',
                'Nude 1913 - by Edvard Munch',
                'Model by the Wicker Chair 1919 - by Edvard Munch',
                'Vampire 1895 - by Edvard Munch',
                'The Village Street 1905 - by Edvard Munch',
                'Woman on the Verandah 1924 - by Edvard Munch',
                'By the Fireplace 1890 - by Edvard Munch']

print(len(vincent_van_gogh), len(edvard_munch))
# Out:
# 50 48

# %%
def search_images(term, max_images=1):
    print(f"Searching for '{term}'")
    return L(ddg_images(term, max_results=max_images)).itemgot('image')

# %%
urls = search_images("Van gogh's chair - by Vincent van Gogh", max_images=1)
urls[0]
# Out:
# Searching for 'Van gogh's chair - by Vincent van Gogh'
# 'https://uploads8.wikiart.org/images/vincent-van-gogh/van-gogh-s-chair-1889.jpg'

# %%
from fastdownload import download_url
dest = 'vincent_van_gogh.jpg'
download_url(urls[0], dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9187/3725840085.py in <cell line: 3>()
#       1 from fastdownload import download_url
#       2 dest = 'vincent_van_gogh.jpg'
# ----> 3 download_url(urls[0], dest, show_progress=False)
#       4
#       5 from fastai.vision.all import *
#
# NameError: name 'urls' is not defined

# %%
download_url(search_images('The Scream 1893 - by Edvard Munch', max_images=1)[0], 'edvard_munch.jpg', show_progress=False)
Image.open('edvard_munch.jpg').to_thumb(256,256)
# Out:
# Searching for 'The Scream 1893 - by Edvard Munch'
# <PIL.Image.Image image mode=RGB size=206x256>

# %%
searches = {'vincent_van_gogh' : vincent_van_gogh,
            'edvard_munch' : edvard_munch}

list(searches.keys())
# Out:
# ['vincent_van_gogh', 'edvard_munch']

# %%
path = Path('vincent_or_edvard')
from time import sleep

for key, values in searches.items():
    dest = (path/key)
    dest.mkdir(exist_ok=True, parents=True)
    for img_link in values:
        download_images(dest, urls=search_images(img_link))
    resize_images(path/key, max_size=400, dest=path/key)
# Out:
# Searching for 'Head of a Peasant Woman - by Vincent van Gogh'
# Searching for 'Starry Night over the Rhone - by Vincent van Gogh'
# Searching for 'Starry Night - by Vincent van Gogh'
# Searching for 'Cafe Terrace at Night - by Vincent van Gogh'
# Searching for 'The Sunflowers - by Vincent van Gogh'
# Searching for 'Self Portraits - by Vincent van Gogh'
# Searching for 'The Night Cafe - by Vincent van Gogh'
# Searching for 'Still Life with Irises - by Vincent van Gogh'
# Searching for 'The Langlois Bridge at Arles - by Vincent van Gogh'
# Searching for 'Enclosed Field with Ploughman - by Vincent van Gogh'
# Searching for 'Landscape with Snow - by Vincent van Gogh'
# Searching for 'Agostina Segatori Sitting in the Café du Tambourin - by Vincent van Gogh'
# Searching for 'The Road Menders - by Vincent van Gogh'
# Searching for 'Tree Roots - by Vincent van Gogh'
# Searching for 'Vase with Daisies and Poppies - by Vincent van Gogh'
# Searching for 'Houses in Auvers - by Vincent van Gogh'
# ...

# %% [markdown]
# ## Step 2: Train our model

# %%
fns = get_image_files(path)
fns
# Out:
# (#96) [Path('vincent_or_edvard/vincent_van_gogh/e37acc28-2bdb-4fe6-8a8d-525126668435.jpg'),Path('vincent_or_edvard/vincent_van_gogh/628d0b8d-402e-4f47-996a-c3674cc32bf0.jpg'),Path('vincent_or_edvard/vincent_van_gogh/aba204c0-b3ed-4038-8f4a-bda23feb0695.jpg'),Path('vincent_or_edvard/vincent_van_gogh/a7d00db1-fcf8-4f93-9253-85dff4a208a0.jpg'),Path('vincent_or_edvard/vincent_van_gogh/75c40841-9fa4-4296-9786-1a764cf15a58.jpg'),Path('vincent_or_edvard/vincent_van_gogh/273ac18c-c00f-41de-bdee-1b84d2b67feb.jpg'),Path('vincent_or_edvard/vincent_van_gogh/da7eb375-15fc-4cd8-af44-ad7d12085ae8.jpg'),Path('vincent_or_edvard/vincent_van_gogh/3ececc6c-5331-4a60-8c0d-5e7439e092ec.jpg'),Path('vincent_or_edvard/vincent_van_gogh/594c7254-dd43-412f-9fd2-48616cda5277.jpg'),Path('vincent_or_edvard/vincent_van_gogh/9e7a23b0-b7c4-43c1-a348-04b64a37d542.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#1) [Path('vincent_or_edvard/edvard_munch/9108d957-e8a9-4a09-9eaf-c1ff888d8fa9.jpg')]

# %%
failed.map(Path.unlink)
# Out:
# (#1) [None]

# %%
len(failed)
# Out:
# 1

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms()).dataloaders(path, bs=32)

# %%
dls.show_batch(max_n=6)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.067338</td>
#       <td>0.921686</td>
#       <td>0.368421</td>
#       <td>00:01</td>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
interp.plot_top_losses(5,nrows=5)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
from fastai.vision.widgets import *

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %% [markdown]
# # Turning Your Model into an Online Application

# %%
#|export

from fastai.vision.all import *
import gradio as gr

# %%
learn.export('model.pkl')

# %%
#|export

learn_inf = load_learner('model.pkl')

# %%
learn_inf.predict('vincent_van_gogh.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('vincent_van_gogh', TensorBase(1), TensorBase([3.1000e-04, 9.9969e-01]))

# %%
learn_inf.dls.vocab
# Out:
# ['edvard_munch', 'vincent_van_gogh']

# %%
#|export

categories = ('edvard_munch', 'vincent_van_gogh')

def classify_images(img):
    pred, idx,probs = learn_inf.predict(img)
    return dict(zip(categories, map(float,probs)))

# %%
classify_images('vincent_van_gogh.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'edvard_munch': 0.00030999636510387063, 'vincent_van_gogh': 0.999690055847168}

# %%
#|export

image = gr.inputs.Image(shape=(256,256))
label = gr.outputs.Label()
examples = ['vincent_van_gogh.jpg', 'edvard_munch.jpg']

intf = gr.Interface(fn= classify_images, inputs=image, outputs=label, examples=examples)
intf.launch(inline=False)
# Out:
# /home/tensor/Downloads/yes/envs/fastai/lib/python3.9/site-packages/gradio/inputs.py:256: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /home/tensor/Downloads/yes/envs/fastai/lib/python3.9/site-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /home/tensor/Downloads/yes/envs/fastai/lib/python3.9/site-packages/gradio/outputs.py:196: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# /home/tensor/Downloads/yes/envs/fastai/lib/python3.9/site-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Running on local URL:  http://127.0.0.1:7860
#
# ...

# %%
from nbdev.export import nb_export

# %%
nb_export('app.ipynb', './')
print('Export successful')
# Out:
# Export successful
